# %%
import pandas
from pandas import ExcelWriter
import openpyxl
import lxml
df = pandas.read_html('https://ruxpert.ru/%D0%A1%D1%82%D0%B0%D1%82%D0%B8%D1%81%D1%82%D0%B8%D0%BA%D0%B0:%D0%A0%D0%BE%D0%B6%D0%B4%D0%B0%D0%B5%D0%BC%D0%BE%D1%81%D1%82%D1%8C_%D0%B2_%D0%A0%D0%BE%D1%81%D1%81%D0%B8%D0%B8', match='Численность родившихся')
print(df)
# Out:
# [     Год  Численность родившихся (тысяч человек)  \
# 0   1950                                 2745997
# 1   1960                                 2782353
# 2   1970                                 1903713
# 3   1980                                 2202779
# 4   1990                                 1988858
# 5   1995                                 1363806
# 6   2000                                 1266800
# 7   2001                                 1311604
# 8   2002                                 1396967
# 9   2003                                 1477301
# 10  2004                                 1502477
# 11  2005                                 1457376
# 12  2006                                 1479637
# 13  2007                                 1610122
# 14  2008                                 1713947
# 15  2009                                 1761687
# 16  2010                                 1788948
# 17  2011                                 1796629
# ...
